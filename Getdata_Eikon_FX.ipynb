# %%
pip install eikon
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
import eikon as ek
import datetime as dt
import pandas as pd

ek.set_app_key('df10b9ab28da455e8b45514b6e6d7c3493995f2c') #Eikon Personal Key eingeben!

# %%
# Währungspaare zu USD mit Refinitiv API
rics = ['EUR=', 'CHF=', 'NZD=','RUB=','SEK=','CNY=','AUD=','CAD=','GBP=','JPY=']
df = ek.get_timeseries(rics, start_date='2010-01-01', end_date='2015-12-31', interval='daily')
df.to_excel('/Users/dany/Documents/ZHAW/Master Banking and Finance/Semester 2/AQM/Arbeit/Eikon_Data/FX10_15.xlsx')
df
# Out:
# Security      EUR=                                     CHF=                  \
# Field        CLOSE    HIGH     LOW     OPEN   COUNT   CLOSE    HIGH     LOW
# Date
# 2014-11-07  1.2452  1.2469  1.2357   1.2373   93839  0.9656   0.974  0.9649
# 2014-11-10   1.242  1.2509  1.2416   1.2451   94823  0.9681  0.9684  0.9614
# 2014-11-11  1.2474  1.2499  1.2393    1.242  102330  0.9642    0.97  0.9622
# 2014-11-12  1.2438  1.2498  1.2417   1.2475  105968  0.9663  0.9679   0.962
# 2014-11-13  1.2475  1.2491  1.2424   1.2438  102718  0.9632  0.9673  0.9619
# 2014-11-14  1.2521  1.2546  1.2397   1.2475  105500  0.9585  0.9688  0.9572
# 2014-11-17  1.2449  1.2577  1.2443   1.2525   85095  0.9648  0.9654   0.955
# 2014-11-18  1.2536  1.2545  1.2441   1.2449   83980  0.9579  0.9654  0.9573
# 2014-11-19  1.2553  1.2599  1.2511   1.2536   89903  0.9565    0.96   0.953
# 2014-11-20  1.2538  1.2575  1.2503   1.2553   85079  0.9583  0.9605   0.955
# ...

# %%
rics = ['EUR=', 'CHF=', 'NZD=','RUB=','SEK=','CNY=','AUD=','CAD=','GBP=','JPY=']
df = ek.get_timeseries(rics, start_date='2016-01-01', end_date='2022-01-01', interval='daily')
df.to_excel('/Users/dany/Documents/ZHAW/Master Banking and Finance/Semester 2/AQM/Arbeit/Eikon_Data/FX16_22.xlsx')
df
# Out:
# Security      EUR=                                    CHF=                  \
# Field        CLOSE    HIGH     LOW    OPEN   COUNT   CLOSE    HIGH     LOW
# Date
# 2020-11-09  1.1813  1.1919  1.1793  1.1881  151736  0.9133  0.9143  0.8979
# 2020-11-10  1.1814  1.1843  1.1778  1.1811  164323  0.9153  0.9175   0.911
# 2020-11-11  1.1777  1.1833  1.1744  1.1808  142791  0.9173  0.9192  0.9132
# 2020-11-12  1.1804  1.1822  1.1757  1.1775  136876  0.9148  0.9178  0.9128
# 2020-11-13  1.1832  1.1836  1.1797  1.1803  117641  0.9126  0.9158  0.9123
# 2020-11-16  1.1853  1.1868  1.1812  1.1827   84284  0.9127  0.9151  0.9095
# 2020-11-17  1.1861  1.1893  1.1841  1.1851   87185  0.9111   0.913  0.9085
# 2020-11-18  1.1852  1.1891  1.1847  1.1862  129048  0.9109  0.9122  0.9088
# 2020-11-19  1.1873  1.1882  1.1815  1.1852  113767  0.9109  0.9138  0.9097
# 2020-11-20  1.1853   1.189  1.1848  1.1874  103337  0.9109  0.9123  0.9088
# ...

# %%
rics = ['EUR=', 'CHF=', 'NZD=','RUB=','SEK=','CNY=','AUD=','CAD=','GBP=','JPY=']
df = ek.get_timeseries(rics, start_date='2022-01-01', end_date='2022-05-01', interval='daily')
df.to_excel('/Users/dany/Documents/ZHAW/Master Banking and Finance/Semester 2/AQM/Arbeit/Eikon_Data/FX22_22.xlsx')
df
# Out:
# Security      EUR=                                    CHF=                  \
# Field        CLOSE    HIGH     LOW    OPEN   COUNT   CLOSE    HIGH     LOW
# Date
# 2022-01-03  1.1294  1.1379  1.1278  1.1352   33872  0.9191  0.9199  0.9102
# 2022-01-04  1.1285  1.1322   1.127  1.1296   47583  0.9161  0.9194  0.9135
# 2022-01-05  1.1313  1.1346  1.1275  1.1286   45063  0.9168  0.9183  0.9139
# 2022-01-06  1.1291  1.1331  1.1283  1.1312   66515  0.9211  0.9224  0.9166
# 2022-01-07  1.1359  1.1364  1.1288  1.1292   44100  0.9188  0.9232  0.9181
# 2022-01-10  1.1324   1.136  1.1283  1.1351   55317  0.9272  0.9275  0.9183
# 2022-01-11  1.1364  1.1374  1.1311  1.1323   58482   0.923  0.9278   0.923
# 2022-01-12  1.1442  1.1452  1.1353  1.1364   60524  0.9141  0.9244  0.9128
# 2022-01-13  1.1453  1.1481  1.1434  1.1441   59440  0.9108  0.9148   0.909
# 2022-01-14  1.1414  1.1482  1.1397  1.1452   63773  0.9139  0.9142  0.9092
# ...
